# %% [markdown]
# # Grover's Algorithm Exercise
#
# Implement a function that returns the optimal number of Grover iterations.
#
# Formula:
#
#     floor(pi/4 * sqrt(N))
#
# Example:
# N = 16 → 3

# %%
# TODO: implement this function
 """
    Return the optimal number of Grover iterations
    """
import math
### BEGIN SOLUTION
def grover_iterations(N):
   

### END SOLUTION

# %%
assert    grover_iterations(4) == 1,
assert       grover_iterations(16) == 3,
assert    grover_iterations(64) == 6,
assert      grover_iterations(256) == 12,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 14
#      11     else:
#      12         print("❌ Not quite. Check your formula and try again.")
# ---> 14 _check()
#
# Cell In[1], line 3, in _check()
#       1 def _check():
#       2     tests = [
# ----> 3         grover_iterations(4) == 1,
#       4         grover_iterations(16) == 3,
#       5         grover_iterations(64) == 6,
#       6         grover_iterations(256) == 12,
#       7     ]
#       9     if all(tests):
#      10         print("✅ Correct! Nice work.")
#
# NameError: name 'grover_iterations' is not defined
