# %%
# AUTOGRADER CELL
# Question: Which data structure has O(1) average time complexity for lookup?

answer = "hash table"  # student should enter the answer here

# %%
# TEST CELL (instructor solution)
# This cell is hidden in student version

correct = "hash table"

# Autograder check
if answer.strip().lower() == correct:
    score = 1
else:
    score = 0
